# %%
import pandas as p
from sklearn import metrics
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as mplot

# %%
iris = p.read_csv('IRIS.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
species = ['Iris-virginica', 'Iris-setosa', 'Iris-versicolor']
slices = [8,11,7]
color = ['r','g','b']
mplot.pie(slices, labels=species, colors=color, shadow=True, startangle=90, explode=(1,0,0))
mplot.legend()
mplot.show()

# %%
species = ['Iris-virginica', 'Iris-setosa', 'Iris-versicolor']
slices = [8,11,7]
color = ['r','g','b']
mplot.pie(slices, labels=species, colors=color, shadow=True, startangle=90, explode=(0,0,0))
mplot.legend()
mplot.show()

# %%
species = ['Iris-virginica', 'Iris-setosa', 'Iris-versicolor']
slices = [8,11,7]
color = ['r','g','b']
mplot.pie(slices, labels=species, colors=color, shadow=True, startangle=90, autopct='%1.2f%%')
mplot.legend()
mplot.show()

# %%
#scatterplot
colors=['red', 'blue','black']
species =['Iris-virginica', 'Iris-setosa', 'Iris-versicolor']

# %%
for i in range(3):
    x=iris[iris['species']==species[i]]
    mplot.scatter(x['sepal_length'], x['sepal_width'], c=colors[i], label=species[i])
mplot.xlabel("sepal length")
mplot.ylabel("sepal width")
mplot.legend()

# %%
for i in range(3):
    x=iris[iris['species']==species[i]]
    mplot.scatter(x['petal_length'], x['petal_width'], c=colors[i], label=species[i])
mplot.xlabel("Petal length")
mplot.ylabel("Petal width")
mplot.legend()

# %%
#histrogram
iris['sepal_length'].hist(color="black")
# Out:
# <AxesSubplot:>

# %%
iris['sepal_width'].hist(color="green")
# Out:
# <AxesSubplot:>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
train, test = train_test_split (iris, test_size=0.25)

# %%
train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 18            5.7          3.8           1.7          0.3      Iris-setosa
# 70            5.9          3.2           4.8          1.8  Iris-versicolor
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 35            5.0          3.2           1.2          0.2      Iris-setosa
# 48            5.3          3.7           1.5          0.2      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 142           5.8          2.7           5.1          1.9   Iris-virginica
# 77            6.7          3.0           5.0          1.7  Iris-versicolor
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 74            6.4          2.9           4.3          1.3  Iris-versicolor
# 148           6.2          3.4           5.4          2.3   Iris-virginica
#
# [112 rows x 5 columns]

# %%
test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 61            5.9          3.0           4.2          1.5  Iris-versicolor
# 128           6.4          2.8           5.6          2.1   Iris-virginica
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 124           6.7          3.3           5.7          2.1   Iris-virginica
# 63            6.1          2.9           4.7          1.4  Iris-versicolor
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 115           6.4          3.2           5.3          2.3   Iris-virginica
# 47            4.6          3.2           1.4          0.2      Iris-setosa
# 30            4.8          3.1           1.6          0.2      Iris-setosa
# 111           6.4          2.7           5.3          1.9   Iris-virginica
# ...

# %%
train_x = train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
train_y = train.species

# %%
train_x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 18            5.7          3.8           1.7          0.3
# 70            5.9          3.2           4.8          1.8
# 42            4.4          3.2           1.3          0.2
# 35            5.0          3.2           1.2          0.2
# 48            5.3          3.7           1.5          0.2
# ..            ...          ...           ...          ...
# 142           5.8          2.7           5.1          1.9
# 77            6.7          3.0           5.0          1.7
# 5             5.4          3.9           1.7          0.4
# 74            6.4          2.9           4.3          1.3
# 148           6.2          3.4           5.4          2.3
#
# [112 rows x 4 columns]

# %%
train_y
# Out:
# 18         Iris-setosa
# 70     Iris-versicolor
# 42         Iris-setosa
# 35         Iris-setosa
# 48         Iris-setosa
#             ...
# 142     Iris-virginica
# 77     Iris-versicolor
# 5          Iris-setosa
# 74     Iris-versicolor
# 148     Iris-virginica
# Name: species, Length: 112, dtype: object

# %%
test_x = test[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
test_y = test.species

# %%
test_x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 61            5.9          3.0           4.2          1.5
# 128           6.4          2.8           5.6          2.1
# 50            7.0          3.2           4.7          1.4
# 124           6.7          3.3           5.7          2.1
# 63            6.1          2.9           4.7          1.4
# 94            5.6          2.7           4.2          1.3
# 7             5.0          3.4           1.5          0.2
# 115           6.4          3.2           5.3          2.3
# 47            4.6          3.2           1.4          0.2
# 30            4.8          3.1           1.6          0.2
# 111           6.4          2.7           5.3          1.9
# 24            4.8          3.4           1.9          0.2
# 32            5.2          4.1           1.5          0.1
# 82            5.8          2.7           3.9          1.2
# 39            5.1          3.4           1.5          0.2
# ...

# %%
test_y
# Out:
# 61     Iris-versicolor
# 128     Iris-virginica
# 50     Iris-versicolor
# 124     Iris-virginica
# 63     Iris-versicolor
# 94     Iris-versicolor
# 7          Iris-setosa
# 115     Iris-virginica
# 47         Iris-setosa
# 30         Iris-setosa
# 111     Iris-virginica
# 24         Iris-setosa
# 32         Iris-setosa
# 82     Iris-versicolor
# 39         Iris-setosa
# 37         Iris-setosa
# 86     Iris-versicolor
# 64     Iris-versicolor
# 140     Iris-virginica
# 3          Iris-setosa
# 119     Iris-virginica
# 11         Iris-setosa
# 26         Iris-setosa
# 21         Iris-setosa
# 100     Iris-virginica
# 83     Iris-versicolor
# 76     Iris-versicolor
# 96     Iris-versicolor
# 143     Iris-virginica
# 126     Iris-virginica
# 6          Iris-setosa
# 103     Iris-virginica
# 16         Iris-setosa
# 65     Iris-versicolor
# 146     Iris-virginica
# 114     Iris-virginica
# 36         Iris-setosa
# 68     Iris-versicolor
# Name: species, dtype: object

# %%
model = svm.SVC()

# %%
model.fit(train_x,train_y)
prediction = model.predict(test_x)

# %%
prediction
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor'], dtype=object)

# %%
metrics.accuracy_score(prediction,test_y)*100
# Out:
# 97.36842105263158

# %%
model = DecisionTreeClassifier()

# %%
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
metrics.accuracy_score(prediction,test_y)*100
# Out:
# 97.36842105263158
